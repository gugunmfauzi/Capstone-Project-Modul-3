# %% [markdown]
# ## **Capstone Project Modul 3**

# %% [markdown]
# ## **Gugun Muhammad Fauzi**

# %% [markdown]
# ## **Bike Sharing**

# %% [markdown]
# **Data Understanding**
#
# Data ini memberikan wawasan mengenai penggunaan sepeda berbagi berdasarkan berbagai faktor seperti cuaca, musim, dan waktu. Ini dapat digunakan untuk menganalisis pola penggunaan dan faktor-faktor yang mempengaruhi permintaan layanan berbagi sepeda.
#
# **Deskripsi Fitur**
#
# | Fitur                      | Deskripsi                                                                                                                                       |
# |----------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------|
# |``dteday``                  | Tanggal saat perjalanan terjadi.                                                                                                                 |
# |``hum``                     | Kelembaban yang dinormalisasi selama perjalanan. Nilainya dibagi menjadi 100 (maksimum).                                                          |
# |``weathersit``              | Kode numerik yang menunjukkan situasi cuaca selama hari tersebut.                                                                                 |
# |                            |1 = Cerah, Sedikit berawan, Sebagian berawan                                                                                                       |
# |                            |2 = Kabut + Berawan, Kabut + Awan yang terpecah, Kabut + Sedikit awan, Kabut                                                                        |
# |                            |3 = Salju Ringan, Hujan Ringan + Badai Petir + Awan yang tersebar, Hujan Ringan + Awan yang tersebar                                               |
# |                            |4 = Hujan Lebat + Es Batu + Badai Petir + Kabut, Salju + Kabut                                                                                      |
# |``holiday``                 | Kode numerik yang menunjukkan apakah hari data yang direkam adalah hari libur atau bukan.                                                          |
# |                            |0 = Bukan Hari Libur                                                                                                                               |
# |                            |1 = Hari Libur                                                                                                                                     |
# |``season``                  | Kode numerik yang menunjukkan musim selama perjalanan.                                                                                            |
# |                            |1 = Musim Dingin                                                                                                                                   |
# |                            |2 = Musim Semi                                                                                                                                     |
# |                            |3 = Musim Panas                                                                                                                                    |
# |                            |4 = Musim Gugur                                                                                                                                    |
# |``atemp``                   | Suhu lingkungan yang tercatat (dalam Celsius), nilainya diperoleh dari (t-tmin)/(tmax-tmin), tmin=-16, tmax=+50 (hanya dalam skala per jam).       |
# |``temp``                    | Suhu yang tercatat (dalam Celsius), nilainya diperoleh dari (t-tmin)/(tmax-tmin), tmin=-8, tmax=+39 (hanya dalam skala per jam).                  |
# |``hr``                      | Total jam perjalanan selama hari (0 hingga 23).                                                                                                   |
# |``casual``                  | Jumlah pengguna kasual (tidak terdaftar) selama perjalanan.                                                                                       |
# |``registered``              | Jumlah pengguna terdaftar selama perjalanan.                                                                                                      |
# |``cnt``                     | Jumlah total penyewaan sepeda termasuk pengguna kasual dan terdaftar.                                                                             |

# %% [markdown]
# **Business Problem**
#
# **A. Context**
#
# Bike-sharing systems adalah generasi baru dari penyewaan sepeda tradisional di mana seluruh proses, mulai dari keanggotaan, penyewaan, hingga pengembalian, telah menjadi otomatis. Sistem ini memungkinkan pengguna untuk menyewa sepeda dari satu lokasi dan mengembalikannya di lokasi lain. Dengan lebih dari 500 program di seluruh dunia yang terdiri dari lebih dari 500 ribu sepeda, sistem ini memainkan peran penting dalam masalah lalu lintas, lingkungan, dan kesehatan. Data yang dihasilkan oleh sistem ini, seperti durasi perjalanan, posisi keberangkatan, dan kedatangan, menjadikannya alat yang berguna untuk memantau mobilitas kota.
#
# **B. Problem Statement**
#
# Tantangan utama dalam sistem berbagi sepeda adalah memastikan ketersediaan sepeda yang memadai di setiap situasi. Kekurangan sepeda dapat mengakibatkan ketidakpuasan pelanggan dan hilangnya kepercayaan, sementara kelebihan stok menyebabkan pemborosan sumber daya dan biaya tinggi untuk manajemen, logistik, dan perawatan. Operator seperti Capital Bikeshare menghadapi tantangan ini dalam menjaga efisiensi operasional dan kepuasan pelanggan.
#
# **C. Goals**
#
# Untuk mengatasi masalah ini, Capital Bikeshare memerlukan alat prediksi yang efektif untuk menentukan jumlah sepeda yang tepat berdasarkan kondisi seperti cuaca, musim, kelembaban, dan suhu. Prediksi yang akurat akan meningkatkan profitabilitas, menjaga efisiensi biaya operasional, dan memastikan kebutuhan pelanggan terpenuhi dengan baik.nsi biaya operasional bagi Capital Bikeshare, serta memastikan kebutuhan pelanggan terpenuhi dengan baik.
#
# **Data Cleaning, Feature Selection, & Feature Engineering**
#
# **A. Data Cleaning**
#
# 1. **Mengatasi Nilai Hilang (Missing Values):**
#    - Nilai hilang dapat menyebabkan bias dan kesalahan dalam model prediksi.
#    - **Metode:** Mengisi nilai hilang dengan mean/median untuk fitur numerik atau mode untuk fitur kategorikal, atau menghapus baris yang memiliki banyak nilai hilang.
#
# 2. **Mengatasi Outliers:**
#    - Outliers dapat mengganggu distribusi data dan mempengaruhi kinerja model.
#    - **Metode:** Identifikasi outliers menggunakan metode seperti IQR atau Z-score dan pertimbangkan untuk menghapus atau mentransformasikannya.
#
# 3. **Standardisasi dan Normalisasi:**
#    - Fitur dengan skala yang berbeda dapat mempengaruhi kinerja algoritma ML tertentu.
#    - **Metode:** Menggunakan metode seperti StandardScaler atau MinMaxScaler dari pustaka seperti scikit-learn.
#
# **B. Feature Selection**
#
# 1. **Analisis Korelasi:**
#    - Mengidentifikasi fitur yang memiliki korelasi tinggi dengan target (``cnt``) dan menghapus fitur yang memiliki korelasi tinggi antar fitur (multikolinieritas).
#    - **Metode:** Menggunakan matriks korelasi atau heatmap.
#
# 2. **Pemilihan Fitur Berdasarkan Kepentingan (Feature Importance):**
#    - Beberapa fitur mungkin lebih penting daripada yang lain untuk model prediksi.
#    - **Metode:** Menggunakan algoritma seperti Random Forest atau Gradient Boosting untuk menentukan pentingnya fitur.
#
# **Feature Engineering**
#
# 1. **Pembuatan Fitur Baru (Feature Creation):**
#    - Fitur baru dapat membantu model menangkap hubungan yang lebih kompleks dalam data.
#    - **Metode:** Membuat fitur-fitur seperti "rush hour" berdasarkan kolom ``hr``, atau "hot day" berdasarkan ``temp``.
#
# 2. **Transformasi Fitur:**
#    - Beberapa fitur mungkin tidak bersifat linear dan memerlukan transformasi agar model dapat memahaminya dengan lebih baik.
#    - **Metode:** Log transformation, polynomial features, atau binning untuk fitur-fitur numerik.
#
# **Analytics (Algorithm & Evaluation Metrics)**
#
# **A. Pemodelan**
#
# 1. **Algoritma Model Machine Learning:**
#    - **Algoritma yang digunakan:** Linear Regression, K-Nearest Neighbors (KNN), Decision Tree, Random Forest, AdaBoost, dan XGBoost.
#    - **Cara kerja:**
#      - **Linear Regression** : Menemukan garis terbaik yang menggambarkan hubungan linear antara fitur input dan target.
#      - **K-Nearest Neighbors (KNN)** : Membuat prediksi berdasarkan rata-rata nilai target dari k tetangga terdekat.
#      - **Decision Tree** : Membagi data secara iteratif berdasarkan fitur untuk membuat pohon keputusan yang memprediksi nilai target.
#      - **Random Forest** : Menggunakan banyak pohon keputusan untuk meningkatkan akurasi dan mengurangi overfitting
#      - **AdaBoost** : Membangun model bertahap dengan menambahkan model sederhana yang memperbaiki kesalahan dari model sebelumnya.
#      - **XGBoost** : Algoritma boosting yang cepat dan kuat, menggunakan gradient boosting untuk membangun model bertahap dan menangani data kompleks.
#
#
# 2. **Limitasi Model:**
#    - **Kapan model dapat dipercaya:** Ketika data terdistribusi dengan baik, tidak ada outliers yang signifikan, dan fitur yang relevan telah dipilih.
#    - **Kapan model tidak dapat dipercaya:** Ketika data memiliki banyak outliers, ada missing values yang signifikan, atau data tidak terdistribusi dengan baik.
#
# **B. Evaluation Metrics**
#
# 1. **Regresi Metrics:**
#    - **MAE (Mean Absolute Error):** Rata-rata dari absolut nilai error.
#    - **MSE (Mean Squared Error):** Rata-rata dari kuadrat nilai error, lebih sensitif terhadap outliers.
#    - **RMSE (Root Mean Squared Error):** Akar kuadrat dari MSE, interpretasi lebih intuitif karena dalam satuan yang sama dengan target.
#    - **MAPE (Mean Absolute Percentage Error):** Rata-rata persentase error, berguna untuk memahami kesalahan relatif terhadap ukuran data.
#    - **R-squared:** Mengukur seberapa baik model menjelaskan variabilitas dari data.
#
# 2. **Pemilihan Metrics:**
#    - **MAE:** Baik untuk data dengan sedikit outliers.
#    - **MSE/RMSE:** Berguna ketika outliers penting untuk diperhatikan.
#    - **MAPE:** Baik untuk pemahaman persentase kesalahan relatif.
#    - **R-squared:** Baik untuk mengetahui seberapa baik model menjelaskan variabilitas data.
#
# **Hubungan dengan Aspek Bisnis:**
#
# - **Akurasi Prediksi:** Memastikan bahwa jumlah sepeda yang tersedia sesuai dengan kebutuhan pengguna.
# - **Efisiensi Operasional:** Mengurangi biaya terkait dengan pengelolaan sepeda yang tidak terpakai.
# - **Kepuasan Pelanggan:** Menyediakan jumlah sepeda yang memadai sehingga meningkatkan kepercayaan dan kepuasan pelanggan terhadap layanan.
#
# Dengan pendekatan ini, model machine learning dapat digunakan untuk meningkatkan efisiensi operasional dan kepuasan pelanggan dalam sistem berbagi sepeda.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset
df = pd.read_csv('D:/BOOTCAMP PWDHK/03. Modul 3/02. Soal/Data Capstone Project Modul 3/data_bike_sharing.csv')
df.head()
# Out:
#        dteday   hum  weathersit  holiday  season   atemp  temp  hr  casual  \
# 0  2011-12-09  0.62           1        0       4  0.3485  0.36  16      24
# 1  2012-06-17  0.64           1        0       2  0.5152  0.54   4       2
# 2  2011-06-15  0.53           1        0       2  0.6212  0.62  23      17
# 3  2012-03-31  0.87           2        0       2  0.3485  0.36   8      19
# 4  2012-07-31  0.55           1        0       3  0.6970  0.76  18      99
#
#    registered  cnt
# 0         226  250
# 1          16   18
# 2          90  107
# 3         126  145
# 4         758  857

# %%
#Informasi mengenai dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12165 entries, 0 to 12164
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dteday      12165 non-null  object
#  1   hum         12165 non-null  float64
#  2   weathersit  12165 non-null  int64
#  3   holiday     12165 non-null  int64
#  4   season      12165 non-null  int64
#  5   atemp       12165 non-null  float64
#  6   temp        12165 non-null  float64
#  7   hr          12165 non-null  int64
#  8   casual      12165 non-null  int64
#  9   registered  12165 non-null  int64
#  10  cnt         12165 non-null  int64
# dtypes: float64(3), int64(7), object(1)
# memory usage: 1.0+ MB

# %% [markdown]
# **Exploratory Data Analysis**

# %%
# Summary statistics
print("\nSummary Statistics:")
df.describe()
# Out:
# Summary Statistics:
#                 hum    weathersit       holiday        season         atemp  \
# count  12165.000000  12165.000000  12165.000000  12165.000000  12165.000000
# mean       0.625451      1.416934      0.029758      2.488615      0.476996
# std        0.192102      0.635937      0.169925      1.106157      0.171857
# min        0.000000      1.000000      0.000000      1.000000      0.000000
# 25%        0.470000      1.000000      0.000000      2.000000      0.333300
# 50%        0.620000      1.000000      0.000000      2.000000      0.484800
# 75%        0.780000      2.000000      0.000000      3.000000      0.621200
# max        1.000000      4.000000      1.000000      4.000000      1.000000
#
#                temp            hr        casual    registered           cnt
# count  12165.000000  12165.000000  12165.000000  12165.000000  12165.000000
# mean       0.498185     11.519770     35.834443    153.436580    189.271023
# ...

# %% [markdown]
# Data ini mencakup berbagai aspek penggunaan sepeda seperti kelembaban, kondisi cuaca, hari libur, musim, suhu, jam, dan jumlah pengguna. Rata-rata kelembaban adalah 0.625, dan kondisi cuaca sebagian besar berada pada kategori 1 dan 2. Hari libur jarang terjadi dengan rata-rata 0.03. Suhu yang dirasakan rata-rata adalah 2.489 dan suhu aktual 0.477. Jam pengambilan data merata sepanjang hari dengan rata-rata 11.52. Jumlah pengguna kasual dan terdaftar bervariasi signifikan, dengan rata-rata masing-masing 35.83 dan 153.44, menghasilkan total rata-rata pengguna per jam sebesar 189.27. Variasi terbesar terlihat pada jumlah pengguna dengan standar deviasi tinggi.

# %%
plt.figure(figsize=(18, 10))

# Total rentals on holidays
plt.subplot(2, 2, 1)
holiday_counts = df['holiday'].value_counts()
sns.barplot(x=holiday_counts.index, y=holiday_counts.values, palette='pastel')
plt.title('Total Rentals on Holidays', size=12)
plt.xlabel('Holiday (0 = No, 1 = Yes)')
plt.ylabel('Total Rentals')
plt.xticks([0, 1], ['No', 'Yes'])
for i, val in enumerate(holiday_counts.values):
    plt.text(i, val + 3, f'{val}', ha='center', va='bottom', size=10)  # Add numerical labels
plt.show()

# Total rentals by season
plt.figure(figsize=(18, 10))
plt.subplot(2, 2, 1)
season_counts = df['season'].value_counts()
sns.barplot(x=season_counts.index, y=season_counts.values, palette='coolwarm')
plt.title('Total Rentals by Season', size=12)
plt.xlabel('Season')
plt.ylabel('Total Rentals')
plt.xticks([1, 2, 3, 4], ['Spring', 'Summer', 'Autumn', 'Winter'])
for i, val in enumerate(season_counts.values):
    plt.text(i, val + 3, f'{val}', ha='center', va='bottom', size=10)  # Add numerical labels
plt.show()

# Total rentals by weather situation
plt.figure(figsize=(18, 10))
plt.subplot(2, 2, 1)
weather_counts = df['weathersit'].value_counts()
sns.barplot(x=weather_counts.index, y=weather_counts.values, palette='muted')
plt.title('Total Rentals by Weather Situation', size=12)
plt.xlabel('Weather Situation')
plt.ylabel('Total Rentals')
plt.xticks([1, 2, 3, 4], ['Clear', 'Cloudy', 'Light Rain', 'Heavy Rain'])
for i, val in enumerate(weather_counts.values):
    plt.text(i, val + 3, f'{val}', ha='center', va='bottom', size=10)  # Add numerical labels
plt.show()

# Total rentals per hour
plt.figure(figsize=(18, 10))
plt.subplot(2, 2, 1)
sns.lineplot(data=df, x='hr', y='cnt', marker='o', color='orange')
plt.title('Total Rentals per Hour', size=12)
plt.xlabel('Hour of the Day')
plt.ylabel('Total Rentals')
plt.show()
# Out:
# c:\Users\Acer\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Acer\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Histograms for all numerical columns
df.hist(bins=30, figsize=(15, 10), layout=(3, 4), color='blue', edgecolor='black')
plt.suptitle('Histograms of Numerical Features', size=15)
plt.show()

# %% [markdown]
# Histogram dari berbagai fitur numerik dalam dataset penggunaan sepeda. Kelembaban (hum) dan suhu (temp dan atemp) menunjukkan distribusi normal dengan puncak di tengah skala. Kondisi cuaca (weathersit) sebagian besar berada di kategori 1 (cuaca baik). Data distribusi waktu (hr) merata sepanjang 24 jam. Hari libur (holiday) jarang terjadi. Jumlah pengguna kasual dan terdaftar serta total pengguna (casual, registered, cnt) menunjukkan distribusi miring ke kanan, dengan sebagian besar data menunjukkan jumlah pengguna yang rendah. Musim (season) terdistribusi merata di empat musim. Histogram ini mengungkap pola dasar dan variasi dalam data penggunaan sepeda.

# %%
# Start Generation Here
plt.figure(figsize=(12, 8))
correlation_matrix = df.select_dtypes(include=['float64', 'int64']).corr()
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar_kws={"shrink": .8})
plt.title('Heatmap of Correlation between Numeric Features', size=15)
plt.show()
# End Generation Here

# %% [markdown]
# Korelasi tinggi terlihat antara suhu aktual (temp) dan suhu yang dirasakan (atemp) dengan nilai 0.99, serta antara jumlah pengguna terdaftar (registered) dan total pengguna (cnt) dengan nilai 0.97. Kelembaban (hum) memiliki korelasi negatif sedang dengan jumlah pengguna kasual (casual) dan total pengguna (cnt), masing-masing -0.35 dan -0.32. Korelasi positif sedang juga terlihat antara suhu (temp dan atemp) dengan jumlah pengguna kasual dan total pengguna. Selain itu, waktu (hr) menunjukkan korelasi positif sedang dengan jumlah pengguna terdaftar dan total pengguna. Heatmap ini membantu mengidentifikasi hubungan kuat dan lemah antara variabel, yang bisa digunakan untuk analisis lebih lanjut dan model prediktif.

# %% [markdown]
# **Data Preprocessing**

# %%
# Create a duplicate of the original dataframe for preprocessing
df_cleaned = df.copy()

# %% [markdown]
# Menghaspus Data Duplikat

# %%
#Check the number of duplicate data before removing
duplicate_count = df_cleaned.duplicated().sum()
print(f'Number of duplicate rows: {duplicate_count}')

# Remove duplicate data
df_cleaned.drop_duplicates(inplace=True)
# Out:
# Number of duplicate rows: 0

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12165 entries, 0 to 12164
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dteday      12165 non-null  object
#  1   hum         12165 non-null  float64
#  2   weathersit  12165 non-null  int64
#  3   holiday     12165 non-null  int64
#  4   season      12165 non-null  int64
#  5   atemp       12165 non-null  float64
#  6   temp        12165 non-null  float64
#  7   hr          12165 non-null  int64
#  8   casual      12165 non-null  int64
#  9   registered  12165 non-null  int64
#  10  cnt         12165 non-null  int64
# dtypes: float64(3), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
# Mengubah tipe fitur 'dteday' menjadi datetime
df_cleaned['dteday'] = pd.to_datetime(df_cleaned['dteday'])

# %%
df_cleaned = df_cleaned.astype({'weathersit':'category', 'holiday':'category', 'season':'category'})

# %% [markdown]
# Mengekstraksi Fitur Tanggal

# %%
df_cleaned['year'] = df_cleaned['dteday'].dt.year
df_cleaned['month'] = df_cleaned['dteday'].dt.month
df_cleaned['day'] = df_cleaned['dteday'].dt.day_of_week

# %%
# Mengecek info setiap fitur
listItem = []

for col in df_cleaned.columns:
    listItem.append([
        col, 
        df_cleaned[col].dtype, 
        df_cleaned[col].isna().sum(), 
        round((df_cleaned[col].isna().sum() / len(df_cleaned[col])) * 100, 2),
        df_cleaned[col].nunique(), 
        list(df_cleaned[col].drop_duplicates().sample(2).values)
    ])

df_cleaned_desc = pd.DataFrame(
    columns=['dataFeatures', 'dataType', 'null', 'nullPct', 'unique', 'uniqueSample'],
    data=listItem
)
df_cleaned_desc
# Out:
#    dataFeatures        dataType  null  nullPct  unique  \
# 0        dteday  datetime64[ns]     0      0.0     731
# 1           hum         float64     0      0.0      89
# 2    weathersit           int64     0      0.0       4
# 3       holiday           int64     0      0.0       2
# 4        season           int64     0      0.0       4
# 5         atemp         float64     0      0.0      65
# 6          temp         float64     0      0.0      50
# 7            hr           int64     0      0.0      24
# 8        casual           int64     0      0.0     305
# 9    registered           int64     0      0.0     742
# 10          cnt           int64     0      0.0     830
# 11         year           int32     0      0.0       2
# 12        month           int32     0      0.0      12
# 13          day           int32     0      0.0       7
#
#                                          uniqueSample
# 0   [2012-10-07T00:00:00.000000000, 2012-08-16T00:...
# ...

# %% [markdown]
# Melakukan Drop Feature

# %%
df_cleaned = df_cleaned.drop(['dteday', 'atemp','casual','registered'], axis=1)

# %% [markdown]
# Merubah Nama Setiap Kolom

# %%
df_cleaned.rename(columns={
    'hum': 'Humidity',
    'weathersit': 'Weather',
    'season': 'Season',
    'temp': 'Temperature',
    'hr': 'Hour',
    'cnt': 'Count',
    'month': 'Month',
    'year': 'Year',
    'day': 'Day',
    'holiday': 'Holiday'
}, inplace=True)

# %%
df_cleaned.head()
# Out:
#    Humidity  Weather  Holiday  Season  Temperature  Hour  Count  Year  Month  \
# 0      0.62        1        0       4         0.36    16    250  2011     12
# 1      0.64        1        0       2         0.54     4     18  2012      6
# 2      0.53        1        0       2         0.62    23    107  2011      6
# 3      0.87        2        0       2         0.36     8    145  2012      3
# 4      0.55        1        0       3         0.76    18    857  2012      7
#
#    Day
# 0    4
# 1    6
# 2    2
# 3    5
# 4    1

# %% [markdown]
# Mengecek Missing Value

# %%
# Display the count of missing values for each column in the cleaned DataFrame
missing_values = df_cleaned.isnull().sum()
print(missing_values)
# Out:
# Humidity       0
# Weather        0
# Holiday        0
# Season         0
# Temperature    0
# Hour           0
# Count          0
# Year           0
# Month          0
# Day            0
# dtype: int64

# %% [markdown]
# Mengecek Outliers

# %%
bp = df_cleaned.boxplot(rot=90, patch_artist=True, boxprops={'facecolor':'red'})

# %% [markdown]
# Dari boxplot yang ditampilkan di atas, terlihat adanya beberapa outlier pada fitur 'count'. Selanjutnya, perlu dilakukan pemeriksaan lebih lanjut terhadap outlier tersebut.

# %%
#Membuat Fungsi Untuk mengecek Outliers
def deteksi_outliers(data):
    # Hitung kuartil pertama (Q1) dan ketiga (Q3)
    q1, q3 = data.quantile([0.25, 0.75])

    # Hitung Interquartile Range (IQR)
    iqr = q3 - q1
    print(f'Rentang Interkuartil (IQR): {iqr}')

    # Tentukan batas atas dan bawah untuk outliers
    batas_bawah = q1 - 1.5 * iqr
    batas_atas = q3 + 1.5 * iqr
    print(f'Batas Bawah: {batas_bawah}')
    print(f'Batas Atas: {batas_atas}')

# %%
# Deteksi outliers pada fitur humidity
deteksi_outliers(df_cleaned['Humidity'])
# Out:
# Rentang Interkuartil (IQR): 0.31000000000000005
# Batas Bawah: 0.004999999999999893
# Batas Atas: 1.245

# %%
# Deteksi outliers pada fitur temp
deteksi_outliers(df_cleaned['Temperature'])
# Out:
# Rentang Interkuartil (IQR): 0.32
# Batas Bawah: -0.13999999999999996
# Batas Atas: 1.1400000000000001

# %%
# Deteksi outliers pada label count
deteksi_outliers(df_cleaned['Count'])
# Out:
# Rentang Interkuartil (IQR): 242.0
# Batas Bawah: -323.0
# Batas Atas: 645.0

# %% [markdown]
# Penghapusan Jumlah Outlier

# %%
# Analisis deskriptif statistik kolom 'Humidity'
print(df_cleaned['Humidity'].describe())

# Cek jumlah data yang tidak berada dalam rentang 0.004999999999999893 dan 1.245
jumlah_outlier = df_cleaned[(df_cleaned['Humidity'] > 1.245) | (df_cleaned['Humidity'] < 0.004999999999999893)].count()['Humidity']
print(f"Jumlah outlier: {jumlah_outlier}")

# Lakukan filtering pada data untuk menghapus outlier
df_cleanded = df_cleaned[(df_cleaned['Humidity'] <= 1.245) & (df_cleaned['Humidity'] >= 0.004999999999999893)]

# Plot distribusi data sebelum dan sesudah filtering
fig, axes = plt.subplots(1,2, figsize=(21, 6))
sns.distplot(df['hum'], ax=axes[0], color='red')
sns.distplot(df_cleanded['Humidity'], ax=axes[1], color='red')
axes[0].set_xlabel('Humidity Sebelum Filtering')
axes[1].set_xlabel('Humidity Setelah Filtering')
axes[0].set_title('Before Filtering', color='red')
axes[1].set_title('After Filtering', color='red')

# Analisis deskriptif statistik kolom 'Humidity' setelah filtering
print(df_cleanded['Humidity'].describe())
# Out:
# count    11827.000000
# mean         0.628451
# std          0.191904
# min          0.000000
# 25%          0.480000
# 50%          0.630000
# 75%          0.790000
# max          1.000000
# Name: Humidity, dtype: float64
# Jumlah outlier: 14
# C:\Users\Acer\AppData\Local\Temp\ipykernel_27136\1871063927.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['hum'], ax=axes[0], color='red')
# ...

# %% [markdown]
# Terdapat outlier sebanyak 14 pada fitu 'Humidity' sehingga perlu adanya penghapusan terhadap outliers tersebut.

# %%
# Analisis deskriptif statistik kolom 'Temperature'
print(df_cleaned['Temperature'].describe())

# Cek jumlah data yang tidak berada dalam rentang -0.09854999999999997 dan 1.0530499999999998
jumlah_outlier = df_cleaned[(df_cleaned['Temperature'] > 1.0530499999999998) | (df_cleaned['Temperature'] < -0.09854999999999997)].count()['Temperature']
print(f"Jumlah outlier pada kolom Temperature: {jumlah_outlier}")
# Out:
# count    12165.000000
# mean         0.498185
# std          0.192492
# min          0.020000
# 25%          0.340000
# 50%          0.500000
# 75%          0.660000
# max          1.000000
# Name: Temperature, dtype: float64
# Jumlah outlier pada kolom Temperature: 0

# %%
# Analisis deskriptif statistik kolom 'Count'
print(df_cleaned['Count'].describe())

# Cek jumlah data yang tidak berada dalam rentang -323.0 dan 645.0
jumlah_outlier = df_cleaned[(df_cleaned['Count'] > 645.0) | (df_cleaned['Count'] < -323.0)].count()['Count']
print(f"Jumlah outlier pada kolom Count: {jumlah_outlier}")

# Lakukan filtering pada data untuk menghapus outlier
df_cleaned = df_cleaned[(df_cleaned['Count'] <= 645.0) & (df_cleaned['Count'] >= -323.0)]

# Plot distribusi data sebelum dan sesudah filtering
fig, axes = plt.subplots(1,2, figsize=(21, 6))
sns.distplot(df['cnt'], ax=axes[0], color='blue', label='Sebelum Filtering')
sns.distplot(df_cleaned['Count'], ax=axes[1], color='red', label='Setelah Filtering')
axes[0].set_xlabel('Count')
axes[1].set_xlabel('Count Setelah Filtering')
axes[0].legend()
axes[1].legend()
plt.show()
# Out:
# count    12165.000000
# mean       189.271023
# std        181.223903
# min          1.000000
# 25%         40.000000
# 50%        142.000000
# 75%        282.000000
# max        970.000000
# Name: Count, dtype: float64
# Jumlah outlier pada kolom Count: 338
# C:\Users\Acer\AppData\Local\Temp\ipykernel_27136\2388658394.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cnt'], ax=axes[0], color='blue', label='Sebelum Filtering')
# ...

# %% [markdown]
# Terdapat outlier sebanyak 338 pada fitu 'Count' sehingga perlu adanya penghapusan terhadap outliers tersebut.

# %%
# # Cek deskriptif statistik kolom 'Count' setelah filtering
df_cleaned['Count'].describe()
# Out:
# count    11827.000000
# mean       173.211634
# std        155.922696
# min          1.000000
# 25%         37.000000
# 50%        136.000000
# 75%        267.000000
# max        645.000000
# Name: Count, dtype: float64

# %%
df_cleaned
# Out:
#        Humidity  Weather  Holiday  Season  Temperature  Hour  Count  Year  \
# 0          0.62        1        0       4         0.36    16    250  2011
# 1          0.64        1        0       2         0.54     4     18  2012
# 2          0.53        1        0       2         0.62    23    107  2011
# 3          0.87        2        0       2         0.36     8    145  2012
# 5          0.72        1        0       4         0.46     0     45  2012
# ...         ...      ...      ...     ...          ...   ...    ...   ...
# 12160      0.75        1        0       1         0.24     7    257  2012
# 12161      0.62        1        0       3         0.78     0    102  2012
# 12162      0.60        2        1       1         0.24     5      6  2012
# 12163      0.77        2        0       2         0.42     2     69  2012
# 12164      0.47        1        0       2         0.64    18    530  2011
#
#        Month  Day
# 0         12    4
# 1          6    6
# 2          6    2
# ...

# %% [markdown]
# Tersisa 11827 baris data yang akan digunakan selanjutnya dalam pemodelan.

# %% [markdown]
# **Modeling**

# %%
from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV, GridSearchCV, KFold
import category_encoders as ce
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from xgboost.sklearn import XGBRegressor
from sklearn.compose import TransformedTargetRegressor
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

# %% [markdown]
# Encoding

# %%
transformer = ColumnTransformer([
    ('One Hot', OneHotEncoder(drop='first', handle_unknown='ignore'), ['Season', 'Weather', 'Holiday']),
    ('Binary', OrdinalEncoder(), ['Day'])
], remainder='passthrough')

# %% [markdown]
# One Hot Encoding diterapkan pada fitur 'season', 'weather', dan 'holiday' karena jumlah item uniknya tidak terlalu banyak dan fitur ini bersifat nominal.
#
# Binary Encoding digunakan untuk fitur 'day' karena jumlah item unik dari fitur 'day' cukup banyak (7) dan bersifat nominal.

# %% [markdown]
# Data Splitting

# %%
#Memisahkan independen vaiavel dengan target
X = df_cleaned.drop(['Count'], axis=1)
y = df_cleaned['Count']

# %% [markdown]
# Train adn Tes Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=19)

# %% [markdown]
# Model Evaluasi

# %%
# Define algoritma yang digunakan
lr = LinearRegression()
knn = KNeighborsRegressor()
dt = DecisionTreeRegressor(random_state=19)
rf = RandomForestRegressor(random_state=19)
ada = AdaBoostRegressor(random_state=19)
xgb = XGBRegressor(random_state=19)

# Pemodelan dilakukan dalam skala logaritmik, namun kemudian di-inverse kembali untuk interpretasi
log_lr = TransformedTargetRegressor(lr, func=np.log, inverse_func=np.exp)
log_knn = TransformedTargetRegressor(knn, func=np.log, inverse_func=np.exp)
log_dt = TransformedTargetRegressor(dt, func=np.log, inverse_func=np.exp)
log_rf = TransformedTargetRegressor(rf, func=np.log, inverse_func=np.exp)
log_ada = TransformedTargetRegressor(ada, func=np.log, inverse_func=np.exp)
log_xgb = TransformedTargetRegressor(xgb, func=np.log, inverse_func=np.exp)

# Scaling data
scaler = StandardScaler()

# Kandidat algoritma
models = [log_lr, log_knn, log_dt, log_rf, log_ada, log_xgb]

score_rmse = []
nilai_mean_rmse = []
nilai_std_rmse = []

score_mae = []
nilai_mean_mae = []
nilai_std_mae = []

score_mape = []
nilai_mean_mape = []
nilai_std_mape = []

# Mencari algoritma terbaik berdasarkan tiap metrics
for i in models:
    
    crossval = KFold(n_splits=5, shuffle=True, random_state=19)

    estimator = Pipeline([
        ('preprocessing', transformer),
        ('scaler', scaler),
        ('model', i)
    ])

    # RMSE
    model_cv_rmse = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=crossval, 
        scoring='neg_root_mean_squared_error', 
        error_score='raise'
        )

    print(model_cv_rmse, i)

    score_rmse.append(model_cv_rmse)
    nilai_mean_rmse.append(model_cv_rmse.mean())
    nilai_std_rmse.append(model_cv_rmse.std())

    # MAE
    model_cv_mae = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=crossval, 
        scoring='neg_mean_absolute_error', 
        error_score='raise'
        )

    print(model_cv_mae, i)

    score_mae.append(model_cv_mae)
    nilai_mean_mae.append(model_cv_mae.mean())
    nilai_std_mae.append(model_cv_mae.std())

    # MAPE
    model_cv_mape = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=crossval, 
        scoring='neg_mean_absolute_percentage_error', 
        error_score='raise'
        )

    print(model_cv_mape, i)

    score_mape.append(model_cv_mape)
    nilai_mean_mape.append(model_cv_mape.mean())
    nilai_std_mape.append(model_cv_mape.std())
# Out:
# [-140.88862618 -146.03814885 -144.92853682 -148.08574353 -142.29682407] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [ -95.20429056  -99.52234064  -99.04861633 -100.90550841  -97.37487153] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [-1.35639827 -1.48512008 -1.37892726 -1.2635593  -1.45033908] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [-97.67712784 -96.3269423  -94.81826533 -97.64412947 -96.84485242] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=KNeighborsRegressor())
# [-61.9110851  -59.68138463 -59.01597756 -62.92078066 -63.05536622] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
# ...

# %%
# evaluasi seluruh kandidat model
pd.DataFrame({
    'Model': ['Linear Regression', 'KNN Regressor', 'DecisionTree Regressor', 'RandomForest Regressor', 'AdaBoost Regressor', 'XGBoost Regressor'],
    'Mean_RMSE': nilai_mean_rmse,
    'Std_RMSE': nilai_std_rmse,
    'Mean_MAE': nilai_mean_mae,
    'Std_MAE': nilai_std_mae,
    'Mean_MAPE': nilai_mean_mape,
    'Std_MAPE': nilai_std_mape
})
# Out:
#                     Model   Mean_RMSE  Std_RMSE   Mean_MAE   Std_MAE  \
# 0       Linear Regression -144.447576  2.580285 -98.411125  1.960651
# 1           KNN Regressor  -96.662263  1.052627 -61.316919  1.668347
# 2  DecisionTree Regressor  -61.861493  1.196644 -36.644134  0.765219
# 3  RandomForest Regressor  -46.277410  2.031131 -27.655206  0.483954
# 4      AdaBoost Regressor -134.418272  6.411048 -84.606535  4.032560
# 5       XGBoost Regressor  -42.236918  1.419944 -25.778170  0.459016
#
#    Mean_MAPE  Std_MAPE
# 0  -1.386869  0.077303
# 1  -0.853788  0.076709
# 2  -0.405784  0.015740
# 3  -0.289302  0.008042
# 4  -0.552994  0.012638
# 5  -0.260104  0.004779

# %% [markdown]
# Tabel tersebut menunjukkan kinerja enam model regresi pada dataset, dievaluasi menggunakan tiga metrik: Root Mean Squared Error (RMSE), Mean Absolute Error (MAE), dan Mean Absolute Percentage Error (MAPE). Nilai yang lebih rendah menunjukkan kinerja yang lebih baik. Berdasarkan hasil, XGBoost Regressor adalah model terbaik karena secara konsisten menunjukkan kinerja terbaik pada ketiga metrik, dengan nilai rata-rata terendah, yaitu RMSE -42.24, MAE -25.78, dan MAPE -0.26. Model ini mampu memprediksi variabel target dengan kesalahan minimal, sehingga menjadi pilihan terbaik untuk dataset ini. Model lainnya, seperti RandomForest Regressor dan DecisionTree Regressor, menunjukkan kinerja yang cukup baik, tetapi masih kalah dengan XGBoost Regressor. Sementara itu, KNN Regressor dan AdaBoost Regressor menunjukkan kinerja yang lebih buruk, dan Linear Regression adalah model terburuk dengan nilai RMSE -144.45, MAE -98.41, dan MAPE -1.39.

# %% [markdown]
# **Model XGBoost**
#
# Model XGBoost adalah sebuah model ensemble yang dibangun berdasarkan konsep Gradient Boosting, namun dengan beberapa perbaikan signifikan. Salah satu perbedaan utama adalah XGBoost mengintegrasikan penalti kompleksitas model (L1 dan L2 regularization) untuk menghindari overfitting, serta memiliki kemampuan komputasi yang lebih efisien dibandingkan dengan Gradient Boosting.
#
# Prinsip kerja XGBoost didasarkan pada metode boosting, yang secara iteratif meningkatkan performa model dengan cara memprediksi residual atau error dari model sebelumnya dan kemudian menambahkannya ke dalam model berikutnya untuk membuat prediksi akhir. Dalam proses ini, XGBoost menggunakan algoritma Gradient Descent untuk meminimalisir residual atau error (loss function) saat menambahkan model baru ke ensemble. Algoritma ini mendorong model untuk fokus pada input yang menghasilkan residual atau error yang tinggi, sehingga jika model berikutnya berhasil menghasilkan residual atau error yang rendah, maka loss atau kerugiannya akan berkurang. Dengan cara iteratif seperti ini, maka akan diperoleh overall model ensemble akhir yang memiliki performa yang baik.

# %% [markdown]
# Predict to Test Set Menggunakan Model XGBoost

# %%
# benchmark model terbaik
models = {'XGB': XGBRegressor(random_state=19)}

score_rmse = []
score_mae = []
score_mape = []

# prediksi pada test set
for i in models:
    model = Pipeline([
        ('preprocessing', transformer),
        ('scaler', scaler),
        ('model', models[i])
        ])
    
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    score_rmse.append(np.sqrt(mean_squared_error(y_test, y_pred)))
    score_mae.append(mean_absolute_error(y_test, y_pred))
    score_mape.append(mean_absolute_percentage_error(y_test, y_pred))

score_before_tuning = pd.DataFrame({'Model': models.keys(),
                                    'RMSE': score_rmse, 
                                    'MAE': score_mae, 
                                    'MAPE': score_mape
                                    })
score_before_tuning
# Out:
#   Model       RMSE        MAE      MAPE
# 0   XGB  40.802313  25.724824  0.419662

# %% [markdown]
# Model XGBoost memiliki tingkat akurasi yang moderat, dengan nilai RMSE sebesar 40,80, MAE sebesar 25,72, dan MAPE sebesar 0,42, yang berarti bahwa prediksi model rata-rata berjarak sekitar 42% dari nilai aktual. Hal ini menunjukkan bahwa model ini memiliki performa yang cukup baik, tetapi belum mencapai tingkat akurasi yang sangat tinggi. Dalam beberapa kasus, model ini masih dapat digunakan untuk membuat prediksi atau mengidentifikasi tren dalam data, namun perlu diingat bahwa akurasi yang lebih tinggi mungkin diperlukan dalam beberapa aplikasi.

# %% [markdown]
# Hyperparameter Tuning

# %%
# Define hyperparameter ranges
param_ranges = {
    'ax_depth': range(3, 11),  # increasing complexity and overfitting risk
    'learning_rate': [i/100 for i in range(1, 51)],  # lower values for better optimization
    'n_estimators': range(100, 251),  # equivalent to boosting rounds
    'ubsample': [i/10 for i in range(2, 10)],  # increasing overfitting risk
    'gamma': range(1, 11),  # increasing model simplicity
    'colsample_bytree': [i/10 for i in range(3, 10)],  # increasing overfitting risk
    'eg_alpha': np.logspace(-1, 1, 10)  # increasing model simplicity
}

# Create hyperparameter space dictionary
hyperparam_space_xgb = {'model__' + key: value for key, value in param_ranges.items()}

# %%
# Benchmark model dengan hyperparameter tuning
xgb = XGBRegressor(random_state=19, verbosity=0)

# Membuat algorithm chains
estimator_xgb = Pipeline([
        ('preprocessing', transformer),
        ('scaler', scaler),
        ('model', xgb)
        ])

crossval = KFold(n_splits=5, shuffle=True, random_state=19)

# Hyperparameter tuning
random_xgb = RandomizedSearchCV(
    estimator_xgb, 
    param_distributions = hyperparam_space_xgb,
    n_iter = 50,
    cv = crossval, 
    scoring = ['neg_root_mean_squared_error', 'neg_mean_absolute_error', 'neg_mean_absolute_percentage_error'], 
    n_jobs = -1,
    refit = 'neg_root_mean_squared_error', # Hanya bisa memilih salah satu metric untuk optimisasi
    random_state = 19  
)

# %%
# Fitting data training untuk mencari parameter terbaik
random_xgb.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=19, shuffle=True),
#                    estimator=Pipeline(steps=[('preprocessing',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('One '
#                                                                                'Hot',
#                                                                                OneHotEncoder(drop='first',
#                                                                                              handle_unknown='ignore'),
#                                                                                ['Season',
#                                                                                 'Weather',
#                                                                                 'Holiday']),
# ...

# %%
# Melihat hasil tuning dalam bentuk dataframe. Diurutkan berdasarkan MAE, MAPE, RMSE
pd.DataFrame(random_xgb.cv_results_).sort_values(by=['rank_test_neg_root_mean_squared_error', 'rank_test_neg_mean_absolute_error', 'rank_test_neg_mean_absolute_percentage_error']).head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 28       0.622657      0.018977         0.043678        0.003315
# 34       0.626820      0.045047         0.040949        0.004360
# 11       0.617464      0.013545         0.045904        0.008467
# 8        0.619517      0.059353         0.037558        0.002237
# 4        0.623891      0.095646         0.037965        0.006934
#
#    param_model__ubsample param_model__n_estimators param_model__learning_rate  \
# 28                   0.5                       242                       0.17
# 34                   0.5                       233                       0.13
# 11                   0.2                       239                       0.14
# 8                    0.3                       199                       0.16
# 4                    0.4                       181                       0.09
#
#    param_model__gamma param_model__eg_alpha param_model__colsample_bytree  \
# ...

# %%
# Cek skor dan params terbaik
print('XGBoost')
print('Best_score:', random_xgb.best_score_)
print('Best_params:', random_xgb.best_params_)
# Out:
# XGBoost
# Best_score: -40.37942602386712
# Best_params: {'model__ubsample': 0.5, 'model__n_estimators': 242, 'model__learning_rate': 0.17, 'model__gamma': 5, 'model__eg_alpha': 0.16681005372000587, 'model__colsample_bytree': 0.9, 'model__ax_depth': 4}

# %% [markdown]
# Predict Test Set With Tuned Model

# %%
# Model XGBoost
model = {'XGB': XGBRegressor(random_state=2009)}

# Define model terhadap estimator terbaik
xgb_tuning = random_xgb.best_estimator_

# Fitting model
xgb_tuning.fit(X_train, y_train)

# Predict test set
y_pred_xgb_tuning = xgb_tuning.predict(X_test)

# Simpan nilai metrics MAE & MAPE setelah tuning
mae_xgb_tuning = mean_absolute_error(y_test, y_pred_xgb_tuning)
mape_xgb_tuning = mean_absolute_percentage_error(y_test, y_pred_xgb_tuning)
rmse_xgb_tuning = np.sqrt(mean_squared_error(y_test, y_pred_xgb_tuning))

score_after_tuning = pd.DataFrame({'MAE': mae_xgb_tuning, 'MAPE': mape_xgb_tuning, 'RMSE': rmse_xgb_tuning}, index=model.keys())
score_after_tuning
# Out:
#            MAE      MAPE      RMSE
# XGB  25.389402  0.413304  40.30006

# %% [markdown]
# Performance Comparison

# %%
# sebelum hyperparameter tuning
pd.DataFrame(score_before_tuning[score_before_tuning['Model']=='XGB'])
# Out:
#   Model       RMSE        MAE      MAPE
# 0   XGB  40.802313  25.724824  0.419662

# %%
# sesudah hyperparameter tuning
score_after_tuning
# Out:
#            MAE      MAPE      RMSE
# XGB  25.389402  0.413304  40.30006

# %%
plt.figure(figsize=(10, 6))
plot = sns.scatterplot(x=y_test, y=y_pred_xgb_tuning, color='red').set(title='Actual vs. Prediction Count', 
                                                                       xlabel='Actual Count', 
                                                                       ylabel='Predicted Count')

# %% [markdown]
# Dari analisis scatterplot di atas, dapat disimpulkan bahwa hasil prediksi model menunjukkan korelasi yang cukup kuat dengan nilai aktual. Namun, masih terlihat adanya pola yang tidak sesuai dengan garis regresi, yang mengindikasikan adanya kemungkinan bias dalam model. Oleh karena itu, perlu dilakukan analisis lebih lanjut untuk mengidentifikasi sumber bias dan meningkatkan akurasi model.

# %% [markdown]
# Feature Importance

# %%
# Plot feature importances
feature_imp = pd.Series(xgb_tuning['model'].feature_importances_, transformer.get_feature_names_out()).sort_values(ascending=False)

plt.figure(figsize=(10, 6))
feature_imp.plot(kind='barh', title='Feature Importances', color='#ff9900', edgecolor='black')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Kesimpulan dan Rekomendasi**

# %% [markdown]
# Berdasarkan hasil pemodelan, fitur 'Hour' terbukti memiliki pengaruh signifikan terhadap variabel target 'Count'. Untuk mengevaluasi kinerja model, digunakan metrik RMSE, MAE, dan MAPE. Setelah melakukan hyperparameter tuning, nilai RMSE yang dihasilkan adalah 40,30. Artinya, jika model ini digunakan untuk memprediksi jumlah penyewa sepeda, maka perkiraan dapat meleset kurang lebih 40 orang dari total aktualnya. Namun, masih terdapat kemungkinan bias yang dapat mempengaruhi akurasi model.
#
# Untuk mengembangkan model yang lebih baik, beberapa rekomendasi yang dapat dilakukan adalah:
#
# Menambahkan fitur yang lebih korelatif dengan target, seperti adanya event tertentu dan jarak lokasi station dengan lokasi perkantoran, sekolah, atau tempat wisata.
# Menambahkan data, seperti data lebih banyak dan lebih dari dua tahun, untuk menganalisis keterkaitan tahun dengan Count dan menggunakan model yang lebih kompleks untuk proses pemodelannya.
# Menggunakan model yang telah dibangun untuk pengembangan lainnya, seperti memprediksi harga rental atau jumlah sepeda yang keluar atau masuk di station tertentu, dan menganalisis lokasi station strategis untuk membuka station baru.

# %%
# Save model
import pickle
import os

final_model = random_xgb.best_estimator_.fit(X_train, y_train)

# Specify the directory to save the model
save_dir = 'D:/BOOTCAMP PWDHK/03. Modul 3/02. Soal/Data Capstone Project Modul 3/BikeSharingModels'

# Create the directory if it doesn't exist
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# Save the model to the specified directory
model_file = 'Model_XGB_BikeSharing.sav'
model_path = os.path.join(save_dir, model_file)
pickle.dump(final_model, open(model_path, 'wb'))

print(f'Model saved to {model_path}')
# Out:
# Model saved to D:/BOOTCAMP PWDHK/03. Modul 3/02. Soal/Data Capstone Project Modul 3/BikeSharingModels\Model_XGB_BikeSharing.sav

# %%
# hasil RMSE pada Test Set menggunakan model yang telah disimpan
np.sqrt(mean_squared_error(y_test, loaded_model.predict(X_test)))
# Out:
# 40.300060396714564
